# %%
from skillos.scripts.skill_repo_scripts import *

# %%
init_repo()

# %%
repo_status()
# Out:
# {'base_dir': 'skillos/storage/skill_repo/SkillStorage',
#  'is_git_repo': True,
#  'branch': 'main',
#  'remote_name': 'origin',
#  'remote_url': '',
#  'dirty': False,
#  'status': ''}

# %%
from skillos.models.skill_model import Skill, SkillState

skill1 = Skill(name="search_web", description="搜索网页", version="1.0.0", state=SkillState.DRAFT)
skill2 = Skill(name="nlp_translate", description="文本翻译", version="0.1.0", state=SkillState.DRAFT)

# %%
add_skill(skill2)
# Out:
# [main e353127] Add/Update Skill nlp_translate v0.1.0
#  3 files changed, 55 insertions(+)
#  create mode 100644 skills/nlp_translate/0.1.0/0.1.0.json
